# %%
# %load_ext autoreload
# %autoreload 2

# %%
"""
For Google Colab

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/repos/Epilepsy_Microglia
# %pip install -q -r requirements.txt
"""

# %%
# project name
project = "epilepsy_microglia_v2"
dataset = "kumar"
gse_accession = "GSE201048"

# %%
# project name
project = "epilepsy_microglia_v2"
dataset = "thrupp"
gse_accession = "GSE153807"

# %%
# project name
project = "epilepsy_microglia_v2"
dataset = "pai"
gse_accession = "GSE140393"

# %%
# environment setting
from src.env_utils import detect_env, get_paths
env = detect_env()
paths = get_paths(project)
print(env)
print(paths["base"])
# Out:
# code-server
# /home/neuro_demo_research/data/active/epilepsy_microglia_v2

# %%
# Pathways and setting
from pathlib import Path
import scanpy as sc
import os
sc.set_figure_params(dpi_save=300, frameon=False)
sc.settings.figdir = paths["plots"]

base = paths["base"]
### label = f"{gse_accession}_{TODAY}"

raw_dir = paths["raw"] / dataset
processed_dir = paths["processed"] / dataset

os.makedirs(raw_dir, exist_ok=True)
os.makedirs(processed_dir, exist_ok=True)

from datetime import date
TODAY = date.today()
print("Today's date: ", TODAY)
# Out:
# Today's date:  2026-03-30

# %%
"""
from sc_utils import sc_load_fix_h5ad, sc_compile_from_dir, sc_compile_from_tar

IO_MODE = "dir"  # {"single", "dir", "tar"}

if IO_MODE == "single":
    adata = sc_load_fix_h5ad(raw_path)
elif IO_MODE == "dir":
    adata = sc_compile_from_dir(raw_dir, label="sample", merge="first")
elif IO_MODE == "tar":
    adata = sc_compile_from_tar(raw_dir, label="sample", merge="first")
else:
    raise ValueError("Invalid IO_MODE")

"""

# %%
import glob
import scanpy as sc

adatas = []
for f in raw_dir.glob("*.fixed.h5ad"):
    adata = sc.read_h5ad(f)
    batch_name = f.stem
    adata.obs["batch"] = batch_name
    adata.obs["batch"] = adata.obs["batch"].astype("category")
    adata.uns["source_file"] = f.name
    print(f.name)
    print(adata)
    adatas.append(adata)
# Out:
# kumar_GSM6049634.fixed.h5ad
# AnnData object with n_obs × n_vars = 7346 × 32738
#     obs: 'batch'
#     var: 'gene_symbols', 'feature_types'
#     uns: 'orientation_fixed', 'source_file'
# kumar_GSM6049642.fixed.h5ad
# AnnData object with n_obs × n_vars = 9164 × 32738
#     obs: 'batch'
#     var: 'gene_symbols', 'feature_types'
#     uns: 'orientation_fixed', 'source_file'
# kumar_GSM6049638.fixed.h5ad
# AnnData object with n_obs × n_vars = 10601 × 32738
#     obs: 'batch'
#     var: 'gene_symbols', 'feature_types'
#     uns: 'orientation_fixed', 'source_file'
# kumar_GSM6049639.fixed.h5ad
# AnnData object with n_obs × n_vars = 7541 × 32738
#     obs: 'batch'
#     var: 'gene_symbols', 'feature_types'
#     uns: 'orientation_fixed', 'source_file'
# kumar_GSM6049640.fixed.h5ad
# AnnData object with n_obs × n_vars = 9491 × 32738
#     obs: 'batch'
#     var: 'gene_symbols', 'feature_types'
#     uns: 'orientation_fixed', 'source_file'
# kumar_GSM6049637.fixed.h5ad
# ...

# %%
n_mad = 3

# %%
adata = adatas[11]
adata
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 adata = adatas[11]
#       2 adata
#
# IndexError: list index out of range

# %%
adata.uns["source_file"]
# Out:
# 'kumar_GSM6049633.fixed.h5ad'

# %% [markdown]
# QC test run
#
# This code aims discovering changes in microglia-like cell proportions according to QC parameters
# 1. Fix all other cutoffs and changing n_MAD from 3, 4, and 5
# 2. Microglia-like cell : P2RY12 > 1.0, TREM2 > 1.0, TMEM119 > 1.0

# %%
# qc
from src.scanpy_utils.qc import sc_add_mt_ribo_hb_qc, sc_plot_qc_mt_rb_hb
from src.scanpy_utils.qc import sc_build_qc_mask, sc_apply_qc_mask, sc_plot_qc_distributions
import scanpy as sc

adata = sc_add_mt_ribo_hb_qc(adata, copy=True)
sc_plot_qc_mt_rb_hb(adata, dataset, TODAY)

# %%
# filter cells with n_mad rule

genes_threshold = 3
mt_threshold = 20
rb_threshold = 40
hb_threshold = 10

qc_mask = sc_build_qc_mask(adata, n_mad, mt_threshold, rb_threshold, hb_threshold)

# check plot
sc_plot_qc_distributions(adata, qc_mask, bins=100)
# Out:
# QC result: 4369 / 5148 cells kept (779 removed)

# %%
# apply cell filters 
adata = sc_apply_qc_mask(adata, qc_mask, copy=True)
# filter genes
sc.pp.filter_genes(adata, min_cells=genes_threshold)
# Out:
# /home/neuro_demo_research/miniconda3/envs/scenv/lib/python3.10/site-packages/scanpy/preprocessing/_simple.py:293: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var["n_cells"] = number

# %%
# normalize
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %%
import numpy as np

# gene index (gene_symbols 기준)
i1 = np.where(adata.var["gene_symbols"] == "P2RY12")[0][0]
i2 = np.where(adata.var["gene_symbols"] == "TREM2")[0][0]
i3 = np.where(adata.var["gene_symbols"] == "TMEM119")[0][0]

# expression vector
x1 = adata.X[:, i1].toarray().ravel() if hasattr(adata.X, "toarray") else adata.X[:, i1]
x2 = adata.X[:, i2].toarray().ravel() if hasattr(adata.X, "toarray") else adata.X[:, i2]
x3 = adata.X[:, i3].toarray().ravel() if hasattr(adata.X, "toarray") else adata.X[:, i3]

t = 1.0

c1 = (x1 > t).sum()
c2 = (x2 > t).sum()
c3 = (x3 > t).sum()

n = adata.n_obs

print("P2RY12:", c1, c1/n)
print("TREM2:", c2, c2/n)
print("TMEM119:", c3, c3/n)
# Out:
# P2RY12: 1606 0.3675898374914168
# TREM2: 799 0.1828793774319066
# TMEM119: 504 0.11535820553902495

# %%
"""
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=3000,
    flavor="seurat_v3",
    inplace=True
)
adata.var.sort_values("highly_variable_rank").head(100)
sc.pl.highly_variable_genes(adata)
# Out:
#   Cell In[32], line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
"""
#if needs annotation : fill in __old_id__ with original ensembl code column
adata.var["ensembl_id"] = adata.var.index.astype(str)
if "gene_symbols" in adata.var:
    adata.var["gene_symbols_raw"] = adata.var["gene_symbols"]
    adata.var.drop(columns=["gene_symbols"], inplace=True)

# %%
"""
from src.scanpy_utils.pipelines import sc_annotate_mygene
adata, report = sc_annotate_mygene(adata, "ensembl_id")

# %%
"""
from src.scanpy_utils.annotations import _check_top_hvg_unmapped
_check_top_hvg_unmapped(adata)

# %%
"""
print("P2RY12" in adata.var["gene_symbol"].values)
print("TREM2" in adata.var["gene_symbol"].values)
print("TMEM119" in adata.var["gene_symbol"].values)
print("SALL1" in adata.var["gene_symbol"].values)

# %%
"""
import pandas as pd

# 1. 새 symbol이 NaN이면 ensembl_id로 대체
new_names = adata.var["gene_symbol"].where(
    adata.var["gene_symbol"].notna(),
    adata.var["ensembl_id"]
)

# 2. 문자열로 강제 변환 (가끔 float 섞이는 사고 방지)
new_names = pd.Index(new_names.astype(str))

# 3. var_names 교체
adata.var_names = new_names

# 4. 중복 자동 해결
adata.var_names_make_unique()

# 0. index 이름 충돌 방지
adata.var.index.name = None

# %%
"""
adata.var

# %%
"""
source_file = adata.uns["source_file"]
adata.write(processed_dir / f"{source_file}_{TODAY}.h5ad")

# %% [markdown]
# This is the end of the notebook

# %%
"""
scvi.model.SCVI.setup_anndata(
    adata,
)
model = scvi.model.SCVI(adata, n_layers=2, n_latent=20)
model.train()
model_dir = os.path.join(OUT_DIR, "model_v3")
os.makedirs(model_dir, exist_ok=True)
model.save(model_dir, save_anndata=False, overwrite=True)
